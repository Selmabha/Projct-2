# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
b = pd.read_csv("titanic.csv")

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
b.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
b=b.dropna(thresh=11)

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 875 entries, 0 to 1306
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     875 non-null    float64
#  1   survived   875 non-null    float64
#  2   name       875 non-null    object
#  3   sex        875 non-null    object
#  4   age        839 non-null    float64
#  5   sibsp      875 non-null    float64
#  6   parch      875 non-null    float64
#  7   ticket     875 non-null    object
#  8   fare       875 non-null    float64
#  9   cabin      291 non-null    object
#  10  embarked   873 non-null    object
#  11  boat       445 non-null    object
#  12  body       119 non-null    float64
#  13  home.dest  720 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 102.5+ KB

# %%
b["age"].fillna(b["age"].mean(),inplace=True)

# %%
b
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1296     3.0       0.0                                 Wirz, Mr. Albert
# 1299     3.0       0.0                              Yasbeck, Mr. Antoni
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000    0.0    0.0   24160  211.3375       B5        S    2
# 1       male   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1296    male  27.0000    0.0    0.0  315154    8.6625      NaN        S  NaN
# 1299    male  27.0000    1.0    0.0    2659   14.4542      NaN        C    C
# 1301    male  45.5000    0.0    0.0    2628    7.2250      NaN        C  NaN
# 1304  female  14.5000    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000    0.0    0.0    2656    7.2250      NaN        C  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1296  131.0                              NaN
# 1299    NaN                              NaN
# 1301  312.0                              NaN
# 1304  328.0                              NaN
# 1306  304.0                              NaN
#
# [875 rows x 14 columns]

# %%
b["fare"].fillna(b["fare"].mean(),inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin        486
# embarked       1
# body         656
# home.dest     72
# dtype: int64

# %%
b["cabin"].value_counts()
# Out:
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# B96 B98            4
# F2                 4
#                   ..
# E40                1
# E60                1
# D45                1
# C103               1
# C148               1
# Name: cabin, Length: 181, dtype: int64

# %%
b["cabin"].fillna('C22',inplace=True)

# %%
b
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1296     3.0       0.0                                 Wirz, Mr. Albert
# 1299     3.0       0.0                              Yasbeck, Mr. Antoni
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000    0.0    0.0   24160  211.3375       B5        S    2
# 1       male   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1296    male  27.0000    0.0    0.0  315154    8.6625      C22        S  NaN
# 1299    male  27.0000    1.0    0.0    2659   14.4542      C22        C    C
# 1301    male  45.5000    0.0    0.0    2628    7.2250      C22        C  NaN
# 1304  female  14.5000    1.0    0.0    2665   14.4542      C22        C  NaN
# 1306    male  26.5000    0.0    0.0    2656    7.2250      C22        C  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1296  131.0                              NaN
# 1299    NaN                              NaN
# 1301  312.0                              NaN
# 1304  328.0                              NaN
# 1306  304.0                              NaN
#
# [875 rows x 14 columns]

# %%
b["embarked"].fillna('S',inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# body         656
# home.dest     72
# dtype: int64

# %%
b["home.dest"].fillna('New York, NY',inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# body         656
# home.dest      0
# dtype: int64

# %%
b
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1296     3.0       0.0                                 Wirz, Mr. Albert
# 1299     3.0       0.0                              Yasbeck, Mr. Antoni
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000    0.0    0.0   24160  211.3375       B5        S    2
# 1       male   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1296    male  27.0000    0.0    0.0  315154    8.6625      C22        S  NaN
# 1299    male  27.0000    1.0    0.0    2659   14.4542      C22        C    C
# 1301    male  45.5000    0.0    0.0    2628    7.2250      C22        C  NaN
# 1304  female  14.5000    1.0    0.0    2665   14.4542      C22        C  NaN
# 1306    male  26.5000    0.0    0.0    2656    7.2250      C22        C  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1296  131.0                     New York, NY
# 1299    NaN                     New York, NY
# 1301  312.0                     New York, NY
# 1304  328.0                     New York, NY
# 1306  304.0                     New York, NY
#
# [875 rows x 14 columns]

# %%
b.drop(['boat'],1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-2cbf7352c88b> in <module>
# ----> 1 b.drop(['boat'],1,inplace=True)
#
# c:\python3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# c:\python3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# c:\python3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# c:\python3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['boat'] not found in axis"

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# body         656
# home.dest      0
# dtype: int64

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# body         656
# home.dest      0
# dtype: int64

# %%
b.drop("body",1,inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# home.dest    0
# dtype: int64

# %%
b.pivot_table('survived',index='age',columns='sex',aggfunc="sum").plot()

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map (b)

# %%
b.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# home.dest    0
# dtype: int64

# %%
Liste=[]
df1=''
for data in b["name"]:
    df1=data.split(",")
    df1=df1[1].split(".")
    df2=df1[0].strip()
    Liste.append((df2))
b["Title"]=Liste

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   Title
# 0                     St Louis, MO    Miss
# 1  Montreal, PQ / Chesterville, ON  Master
# 2  Montreal, PQ / Chesterville, ON    Miss
# 3  Montreal, PQ / Chesterville, ON      Mr
# 4  Montreal, PQ / Chesterville, ON     Mrs

# %%
b[['pclass','survived']].groupby(['pclass'],as_index=True).mean()
# Out:
#         survived
# pclass
# 1.0     0.621993
# 2.0     0.450593
# 3.0     0.251082

# %%
sns.factorplot('sex',data=b,kind="count",hue='Title')
# Out:
# c:\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty" ,

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }
b["Title"].str.strip()
# Out:
# 0         Miss
# 1       Master
# 2         Miss
# 3           Mr
# 4          Mrs
#          ...
# 1294        Mr
# 1296        Mr
# 1301        Mr
# 1304      Miss
# 1306        Mr
# Name: Title, Length: 775, dtype: object

# %%
b["Title"]=b["Title"].str.strip()

# %%
b["Title"].replace(Title_Dictionary,inplace=True)

# %%
b["Title"].values
# Out:
# array(['Miss', 'Master', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Officer', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Officer', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Officer', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Officer', 'Master', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Royalty', 'Royalty', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Officer', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Royalty', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Officer', 'Mrs', 'Mrs',
#        'Royalty', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Royalty', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Officer', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Royalty', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs',
#        'Mrs', 'Master', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Officer', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Master', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Miss',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Miss',
#        'Officer', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Officer', 'Mrs', 'Mrs',
#        'Officer', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Officer', 'Officer', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master',
#        'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Officer', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Master', 'Master', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Master', 'Miss', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Master', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Miss',
#        'Miss', 'Miss', 'Miss', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Master', 'Master', 'Master',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Master', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Master',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Miss', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Miss', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Master',
#        'Master', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs'],
#       dtype=object)

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   Title
# 0                     St Louis, MO    Miss
# 1  Montreal, PQ / Chesterville, ON  Master
# 2  Montreal, PQ / Chesterville, ON    Miss
# 3  Montreal, PQ / Chesterville, ON      Mr
# 4  Montreal, PQ / Chesterville, ON     Mrs

# %%
sns.factorplot('sex',data=b,kind="count",hue='Title')

# %%
x=pd.DataFrame()
x["Family"]=b["sibsp"]+b["parch"]

x
# Out:
#       Family
# 0        0.0
# 1        3.0
# 2        3.0
# 3        3.0
# 4        3.0
# ...      ...
# 1305     1.0
# 1306     0.0
# 1307     0.0
# 1308     0.0
# 1309     NaN
#
# [1310 rows x 1 columns]

# %%
b["Family"]=x

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  Family
# 0                     St Louis, MO     0.0
# 1  Montreal, PQ / Chesterville, ON     3.0
# 2  Montreal, PQ / Chesterville, ON     3.0
# 3  Montreal, PQ / Chesterville, ON     3.0
# 4  Montreal, PQ / Chesterville, ON     3.0
